# %%
import numpy as np
import pandas as pd
import pydicom

# %%
dir(pydicom)
# Out:
# ['DataElement',
#  'Dataset',
#  'FileDataset',
#  'Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__dicom_version__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '__version_info__',
#  '_dicom_dict',
#  '_private_dict',
#  '_uid_dict',
#  '_version',
#  'charset',
#  'config',
#  'data',
#  'datadict',
#  'dataelem',
#  'dataset',
#  'dcmread',
#  'dcmwrite',
#  'dicomdir',
#  'encaps',
#  'encoders',
#  'errors',
#  'filebase',
#  'filereader',
#  'fileutil',
#  'filewriter',
#  'jsonrep',
#  'misc',
#  'multival',
#  'overlays',
#  'pixel_data_handlers',
#  'read_file',
#  'sequence',
#  'tag',
#  'uid',
#  'util',
#  'valuerep',
#  'values',
#  'warnings',
#  'waveforms',
#  'write_file']

# %%
pydicom.__version__
# Out:
# '2.3.1'

# %%
ds = pydicom.read_file("E:/IBEC/NAFLD_PostDoc/2023_04_21_MatlabMRIDataProcessing/MRIImages/MRIm3.dcm")

# %%
ds
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 190
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: MR Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 2.16.756.5.5.100.8323328.115859.1647367302.1.2
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.6.0
# (0002, 0013) Implementation Version Name         SH: 'OFFIS_DCMTK_360'
# -------------------------------------------------
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'OTHER']
# (0008, 0012) Instance Creation Date              DA: '20220331'
# (0008, 0013) Instance Creation Time              TM: '105011'
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 2.16.756.5.5.100.8323328.115859.1647367302.1.2
# (0008, 0020) Study Date                          DA: '20220314'
# (0008, 0021) Series Date                         DA: '20220315'
# (0008, 0022) Acquisition Date                    DA: '20220315'
# (0008, 0030) Study Time                          TM: '110733'
# (0008, 0031) Series Time                         TM: '110142'
# (0008, 0032) Acquisition Time                    TM: '110116'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0070) Manufacturer                        LO: 'Bruker BioSpin MRI GmbH'
# (0008, 0080) Institution Name                    LO: 'UCSF'
# (0008, 0090) Referring Physician's Name          PN: 'XJI'
# (0008, 0201) Timezone Offset From UTC            SH: '-0700'
# (0008, 1090) Manufacturer's Model Name           LO: 'BioSpec 3T'
# (0010, 0010) Patient's Name                      PN: 'PerfusionPhantom-8WellPlate'
# (0010, 0020) Patient ID                          LO: 'PerfusionPhantom-8WellPlate'
# (0010, 0030) Patient's Birth Date                DA: '20220315'
# (0010, 0040) Patient's Sex                       CS: 'O'
# (0010, 1030) Patient's Weight                    DS: '0.001'
# (0010, 2201) Patient Species Description         LO: 'MATERIAL'
# (0010, 2210) Anatomical Orientation Type         CS: 'BIPED'
# (0010, 2292) Patient Breed Description           LO: ''
# (0010, 2293)  Patient Breed Code Sequence  0 item(s) ----
# (0010, 2294)  Breed Registration Sequence  0 item(s) ----
# (0010, 2297) Responsible Person                  PN: ''
# (0010, 2299) Responsible Organization            LO: 'UCSF'
# (0018, 0020) Scanning Sequence                   CS: ['RM', 'GR']
# (0018, 0021) Sequence Variant                    CS: 'SP'
# (0018, 0022) Scan Options                        CS: 'PFF'
# (0018, 0023) MR Acquisition Type                 CS: '2D'
# (0018, 0024) Sequence Name                       SH: 'Bruker:FLASH'
# (0018, 0050) Slice Thickness                     DS: '9.0'
# (0018, 0080) Repetition Time                     DS: '60.0'
# (0018, 0081) Echo Time                           DS: '2.5'
# (0018, 0083) Number of Averages                  DS: '3.0'
# (0018, 0084) Imaging Frequency                   DS: '127.6351247'
# (0018, 0085) Imaged Nucleus                      SH: '1H'
# (0018, 0087) Magnetic Field Strength             DS: '2.997818601'
# (0018, 0089) Number of Phase Encoding Steps      IS: '128'
# (0018, 0091) Echo Train Length                   IS: '1'
# (0018, 0094) Percent Phase Field of View         DS: '100.0'
# (0018, 0095) Pixel Bandwidth                     DS: '122.0703125'
# (0018, 1000) Device Serial Number                LO: '10235995'
# (0018, 1020) Software Versions                   LO: ['ParaVision Acquisition 6.0.1', 'ParaVision 6.0.1']
# (0018, 1030) Protocol Name                       LO: '1_Localizer'
# (0018, 1310) Acquisition Matrix                  US: [0, 96, 96, 0]
# (0018, 1312) In-plane Phase Encoding Direction   CS: 'ROW'
# (0018, 1314) Flip Angle                          DS: '40.0'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0020, 000d) Study Instance UID                  UI: 2.16.756.5.5.100.8323328.107569.1647281253.3
# (0020, 000e) Series Instance UID                 UI: 2.16.756.5.5.100.8323328.115859.1647367302.1
# (0020, 0010) Study ID                            SH: '20220314-perfusi'
# (0020, 0011) Series Number                       IS: '290001'
# (0020, 0012) Acquisition Number                  IS: '3'
# (0020, 0013) Instance Number                     IS: '3'
# (0020, 0032) Image Position (Patient)            DS: [25.35701983, 0.2324944259, 25]
# (0020, 0037) Image Orientation (Patient)         DS: [-0.9977792331, 0.06660782296, 0, 0, 0, -1]
# (0020, 0052) Frame of Reference UID              UI: 2.16.756.5.5.100.8323328.115859.1647367302.1.7
# (0020, 1002) Images in Acquisition               IS: '3'
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: '-1.920953997'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 256
# (0028, 0011) Columns                             US: 256
# (0028, 0030) Pixel Spacing                       DS: [0.1953125, 0.1953125]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0106) Smallest Image Pixel Value          SS: 0
# (0028, 0107) Largest Image Pixel Value           SS: 6205
# (0028, 1052) Rescale Intercept                   DS: '0.0'
# (0028, 1053) Rescale Slope                       DS: '0.004470916133'
# (0028, 1054) Rescale Type                        LO: 'US'
# (7fe0, 0010) Pixel Data                          OW: Array of 131072 elements

# %%
ds2 = pydicom.dcmread("E:/IBEC/NAFLD_PostDoc/2023_04_21_MatlabMRIDataProcessing/MRIImages/MRIm3.dcm")

# %%
ds2
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 190
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: MR Image Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 2.16.756.5.5.100.8323328.115859.1647367302.1.2
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 1.2.276.0.7230010.3.0.3.6.0
# (0002, 0013) Implementation Version Name         SH: 'OFFIS_DCMTK_360'
# -------------------------------------------------
# (0008, 0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'OTHER']
# (0008, 0012) Instance Creation Date              DA: '20220331'
# (0008, 0013) Instance Creation Time              TM: '105011'
# (0008, 0016) SOP Class UID                       UI: MR Image Storage
# (0008, 0018) SOP Instance UID                    UI: 2.16.756.5.5.100.8323328.115859.1647367302.1.2
# (0008, 0020) Study Date                          DA: '20220314'
# (0008, 0021) Series Date                         DA: '20220315'
# (0008, 0022) Acquisition Date                    DA: '20220315'
# (0008, 0030) Study Time                          TM: '110733'
# (0008, 0031) Series Time                         TM: '110142'
# (0008, 0032) Acquisition Time                    TM: '110116'
# (0008, 0050) Accession Number                    SH: ''
# (0008, 0060) Modality                            CS: 'MR'
# (0008, 0070) Manufacturer                        LO: 'Bruker BioSpin MRI GmbH'
# (0008, 0080) Institution Name                    LO: 'UCSF'
# (0008, 0090) Referring Physician's Name          PN: 'XJI'
# (0008, 0201) Timezone Offset From UTC            SH: '-0700'
# (0008, 1090) Manufacturer's Model Name           LO: 'BioSpec 3T'
# (0010, 0010) Patient's Name                      PN: 'PerfusionPhantom-8WellPlate'
# (0010, 0020) Patient ID                          LO: 'PerfusionPhantom-8WellPlate'
# (0010, 0030) Patient's Birth Date                DA: '20220315'
# (0010, 0040) Patient's Sex                       CS: 'O'
# (0010, 1030) Patient's Weight                    DS: '0.001'
# (0010, 2201) Patient Species Description         LO: 'MATERIAL'
# (0010, 2210) Anatomical Orientation Type         CS: 'BIPED'
# (0010, 2292) Patient Breed Description           LO: ''
# (0010, 2293)  Patient Breed Code Sequence  0 item(s) ----
# (0010, 2294)  Breed Registration Sequence  0 item(s) ----
# (0010, 2297) Responsible Person                  PN: ''
# (0010, 2299) Responsible Organization            LO: 'UCSF'
# (0018, 0020) Scanning Sequence                   CS: ['RM', 'GR']
# (0018, 0021) Sequence Variant                    CS: 'SP'
# (0018, 0022) Scan Options                        CS: 'PFF'
# (0018, 0023) MR Acquisition Type                 CS: '2D'
# (0018, 0024) Sequence Name                       SH: 'Bruker:FLASH'
# (0018, 0050) Slice Thickness                     DS: '9.0'
# (0018, 0080) Repetition Time                     DS: '60.0'
# (0018, 0081) Echo Time                           DS: '2.5'
# (0018, 0083) Number of Averages                  DS: '3.0'
# (0018, 0084) Imaging Frequency                   DS: '127.6351247'
# (0018, 0085) Imaged Nucleus                      SH: '1H'
# (0018, 0087) Magnetic Field Strength             DS: '2.997818601'
# (0018, 0089) Number of Phase Encoding Steps      IS: '128'
# (0018, 0091) Echo Train Length                   IS: '1'
# (0018, 0094) Percent Phase Field of View         DS: '100.0'
# (0018, 0095) Pixel Bandwidth                     DS: '122.0703125'
# (0018, 1000) Device Serial Number                LO: '10235995'
# (0018, 1020) Software Versions                   LO: ['ParaVision Acquisition 6.0.1', 'ParaVision 6.0.1']
# (0018, 1030) Protocol Name                       LO: '1_Localizer'
# (0018, 1310) Acquisition Matrix                  US: [0, 96, 96, 0]
# (0018, 1312) In-plane Phase Encoding Direction   CS: 'ROW'
# (0018, 1314) Flip Angle                          DS: '40.0'
# (0018, 5100) Patient Position                    CS: 'HFS'
# (0020, 000d) Study Instance UID                  UI: 2.16.756.5.5.100.8323328.107569.1647281253.3
# (0020, 000e) Series Instance UID                 UI: 2.16.756.5.5.100.8323328.115859.1647367302.1
# (0020, 0010) Study ID                            SH: '20220314-perfusi'
# (0020, 0011) Series Number                       IS: '290001'
# (0020, 0012) Acquisition Number                  IS: '3'
# (0020, 0013) Instance Number                     IS: '3'
# (0020, 0032) Image Position (Patient)            DS: [25.35701983, 0.2324944259, 25]
# (0020, 0037) Image Orientation (Patient)         DS: [-0.9977792331, 0.06660782296, 0, 0, 0, -1]
# (0020, 0052) Frame of Reference UID              UI: 2.16.756.5.5.100.8323328.115859.1647367302.1.7
# (0020, 1002) Images in Acquisition               IS: '3'
# (0020, 1040) Position Reference Indicator        LO: ''
# (0020, 1041) Slice Location                      DS: '-1.920953997'
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 256
# (0028, 0011) Columns                             US: 256
# (0028, 0030) Pixel Spacing                       DS: [0.1953125, 0.1953125]
# (0028, 0100) Bits Allocated                      US: 16
# (0028, 0101) Bits Stored                         US: 16
# (0028, 0102) High Bit                            US: 15
# (0028, 0103) Pixel Representation                US: 1
# (0028, 0106) Smallest Image Pixel Value          SS: 0
# (0028, 0107) Largest Image Pixel Value           SS: 6205
# (0028, 1052) Rescale Intercept                   DS: '0.0'
# (0028, 1053) Rescale Slope                       DS: '0.004470916133'
# (0028, 1054) Rescale Type                        LO: 'US'
# (7fe0, 0010) Pixel Data                          OW: Array of 131072 elements

# %%
import matplotlib.pyplot as plt

# %%
# Credits: https://pydicom.github.io/pydicom/stable/auto_examples/input_output/plot_read_dicom.html#sphx-glr-auto-examples-input-output-plot-read-dicom-py
if 'PixelData' in ds2:
    rows = int(ds2.Rows)
    cols = int(ds2.Columns)
    print("Image size.......: {rows:d} x {cols:d}, {size:d} bytes".format(
        rows=rows, cols=cols, size=len(ds2.PixelData)))
    if 'PixelSpacing' in ds2:
        print("Pixel spacing....:", ds2.PixelSpacing)
# Out:
# Image size.......: 256 x 256, 131072 bytes
# Pixel spacing....: [0.1953125, 0.1953125]

# %%
plt.imshow(ds2.pixel_array, cmap=plt.cm.bone) 
plt.show()
